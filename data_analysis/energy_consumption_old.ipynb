# %% [markdown]
# ## Energy of different consensus algorithms

# %% [markdown]
# ### SHA-256 Proof-of-Work

# %%
sha_256 = mining_data[mining_data['algorithm'] == "SHA-256"].copy()
sha_256
# Out:
#              Market Cap ($)    Price  Volume (24h)  Circulating Supply code  \
# Name
# bitcoin        1.582063e+11  8669.95   36604114509            18247675  BTC
# bitcoincash    5.865094e+09   320.35    4251315222            18308363  BCH
# bitcoinsv      4.250278e+09   232.18    2250321444            18305602  BSV
#
#             algorithm    difficulty  block_time  position
# Name
# bitcoin       SHA-256  1.554675e+13       599.0         0
# bitcoincash   SHA-256  5.728909e+11       600.0         3
# bitcoinsv     SHA-256  4.315897e+11       578.0         5

# %%
# All correct! 
sha_256['total_hash'] = sha_256['difficulty']*2**48/(65535) # or 2^32 
sha_256['nethash'] = sha_256['total_hash']/sha_256['block_time']
sha_256
# Out:
#              Market Cap ($)    Price  Volume (24h)  Circulating Supply code  \
# Name
# bitcoin        1.582063e+11  8669.95   36604114509            18247675  BTC
# bitcoincash    5.865094e+09   320.35    4251315222            18308363  BCH
# bitcoinsv      4.250278e+09   232.18    2250321444            18305602  BSV
#
#             algorithm    difficulty  block_time  position    total_hash  \
# Name
# bitcoin       SHA-256  1.554675e+13       599.0         0  6.677378e+22
# bitcoincash   SHA-256  5.728909e+11       600.0         3  2.460585e+21
# bitcoinsv     SHA-256  4.315897e+11       578.0         5  1.853692e+21
#
#                   nethash
# Name
# bitcoin      1.114754e+20
# bitcoincash  4.100975e+18
# bitcoinsv    3.207080e+18

# %% [markdown]
# ### Equihash

# %%
equihash = mining_data[mining_data['algorithm'] == "Equihash"].copy()
equihash['(n,k)'] = [(200,9),(144,5),(0,0),(200,9)]
equihash
# Out:
#              Market Cap ($)      Price  Volume (24h)  Circulating Supply code  \
# Name
# zcash           460911098.0  50.030000     311995941             9212506  ZEC
# bitcoingold     170070863.0   9.710000      39606584            17513924  BTG
# horizen          85591701.0  10.020000       1543230             8539588  ZEN
# komodo           75922471.0   0.640276       2536293           118577670  KMD
#
#             algorithm    difficulty  block_time  position     (n,k)
# Name
# zcash        Equihash  6.030782e+07        75.0        25  (200, 9)
# bitcoingold  Equihash  1.765900e+05       600.0        38  (144, 5)
# horizen      Equihash  1.404942e+07       150.0        63    (0, 0)
# komodo       Equihash  2.007803e+08        62.0        69  (200, 9)

# %%
equihash['alg_runs'] = 2**13*equihash['difficulty']/2 # Starting difficulty of Zcash, times the relative difficulty, divided by amount of solution
equihash['hashrate'] = equihash['alg_runs']/equihash['block_time']
equihash
# Out:
#              Market Cap ($)      Price  Volume (24h)  Circulating Supply code  \
# Name
# zcash           460911098.0  50.030000     311995941             9212506  ZEC
# bitcoingold     170070863.0   9.710000      39606584            17513924  BTG
# horizen          85591701.0  10.020000       1543230             8539588  ZEN
# komodo           75922471.0   0.640276       2536293           118577670  KMD
#
#             algorithm    difficulty  block_time  position     (n,k)  \
# Name
# zcash        Equihash  6.030782e+07        75.0        25  (200, 9)
# bitcoingold  Equihash  1.765900e+05       600.0        38  (144, 5)
# horizen      Equihash  1.404942e+07       150.0        63    (0, 0)
# komodo       Equihash  2.007803e+08        62.0        69  (200, 9)
#
#                  alg_runs      hashrate
# Name
# zcash        2.470208e+11  3.293611e+09
# bitcoingold  7.233126e+08  1.205521e+06
# horizen      5.754643e+10  3.836429e+08
# komodo       8.223963e+11  1.326446e+10

# %% [markdown]
# ### Scrypt

# %%
scrypt = mining_data[mining_data['algorithm'] == "Scrypt"].copy()
scrypt
# Out:
#           Market Cap ($)      Price  Volume (24h)  Circulating Supply  code  \
# Name
# litecoin    3.801726e+09  59.210000    4433870551            64202387   LTC
# dogecoin    2.820381e+08   0.002283     166256231        123544326274  DOGE
# digibyte    7.191128e+07   0.005583        824878         12880917393   DGB
# verge       5.942903e+07   0.003670        691527         16193811143   XVG
#
#          algorithm    difficulty  block_time  block_reward  exchange_rate  \
# Name
# litecoin    Scrypt  5.975834e+06       140.0     12.500000      75.559274
# dogecoin    Scrypt  2.453764e+06        62.0  10000.000000       0.002604
# digibyte    Scrypt  2.286140e+04        15.0    665.639774       0.005608
# verge       Scrypt  5.664491e+03        30.0    730.000000       0.003680
#
#           position  reward_per_sec
# Name
# litecoin         6        6.746364
# dogecoin        32        0.420077
# digibyte        71        0.248842
# verge           81        0.089546

# %%
# TODO: all litecoin! 
scrypt.loc['litecoin','alg_runs'] = 2**32*scrypt.loc['litecoin','difficulty']/scrypt.loc['litecoin','block_time'] # https://litecoin.info/index.php/Difficulty
scrypt
# Out:
#           Market Cap ($)      Price  Volume (24h)  Circulating Supply  code  \
# Name
# litecoin    3.801726e+09  59.210000    4433870551            64202387   LTC
# dogecoin    2.820381e+08   0.002283     166256231        123544326274  DOGE
# digibyte    7.191128e+07   0.005583        824878         12880917393   DGB
# verge       5.942903e+07   0.003670        691527         16193811143   XVG
#
#          algorithm    difficulty  block_time  block_reward  exchange_rate  \
# Name
# litecoin    Scrypt  5.975834e+06       140.0     12.500000      75.559274
# dogecoin    Scrypt  2.453764e+06        62.0  10000.000000       0.002604
# digibyte    Scrypt  2.286140e+04        15.0    665.639774       0.005608
# verge       Scrypt  5.664491e+03        30.0    730.000000       0.003680
#
#           position  reward_per_sec      alg_runs
# Name
# litecoin         6        6.746364  1.833287e+14
# dogecoin        32        0.420077           NaN
# digibyte        71        0.248842           NaN
# verge           81        0.089546           NaN

# %% [markdown]
# ### EtHash

# %%
ethash = mining_data[mining_data['algorithm'] == "EtHash"].copy()
ethash
# Out:
#                  Market Cap ($)   Price  Volume (24h)  Circulating Supply  \
# Name
# ethereum           2.440093e+10  221.98   17556366958           109925923
# ethereumclassic    9.465897e+08    8.14    1614433225           116313299
#
#                 code algorithm    difficulty  block_time  block_reward  \
# Name
# ethereum         ETH    EtHash  2.244509e+15        15.0           2.0
# ethereumclassic  ETC    EtHash  1.543936e+14        15.0           4.0
#
#                  exchange_rate  position  reward_per_sec
# Name
# ethereum            224.138591         1       29.885145
# ethereumclassic       8.145615        17        2.172164

# %%
ethash['hashrate'] = ethash['difficulty']/ethash['block_time']
ethash
# Out:
#                  Market Cap ($)   Price  Volume (24h)  Circulating Supply  \
# Name
# ethereum           2.440093e+10  221.98   17556366958           109925923
# ethereumclassic    9.465897e+08    8.14    1614433225           116313299
#
#                 code algorithm    difficulty  block_time  block_reward  \
# Name
# ethereum         ETH    EtHash  2.244509e+15        15.0           2.0
# ethereumclassic  ETC    EtHash  1.543936e+14        15.0           4.0
#
#                  exchange_rate  position  reward_per_sec      hashrate
# Name
# ethereum            224.138591         1       29.885145  1.496340e+14
# ethereumclassic       8.145615        17        2.172164  1.029291e+13

# %% [markdown]
# +- same as other online clients

# %% [markdown]
# ## Lower bound

# %% [markdown]
# In this approach, we look at the number of hashes the miners are actually computing, which we know by observing the difficulty of each block. If we then assume that all miners are using the most efficient hardware, we can derive a lower bound on electricity consumption.

# %% [markdown]
# As of writing, the most efficient hardware is the 'Antminer S9', which calculates 14TH/s
# https://www.buybitcoinworldwide.com/mining/hardware/

# %%
max_hash_rate = 14*10**12 # Hashes per second
joules_per_hash = 0.1/(10**9) # Joules per hash
energy_cons = max_hash_rate*joules_per_hash # In Watt
energy_cons
# Out:
# 1400.0

# %%
def lower_bound(coin):
    """
    Return a lower bound on the amount of energy (in W) needed for a cryptocurrency using the SHA-256 algorithm
    """
    # Hashrate per second needed
    hashrate = coin['nethash']
    # Amount of ASIC's needed to generate this hashrate
    num_hardware = hashrate/max_hash_rate
    total_energy = num_hardware*energy_cons
    return total_energy

# %%
energy = lower_bound(sha_256.loc['Bitcoin'])

# %%
# Convert W to Wh
energy_Wh = energy*3600

# %%
print(f"The Bitcoin cryptocurrency consumes, as a minimum {energy_Wh/10**12} TWh of energy")
# Out:
# The Bitcoin cryptocurrency consumes, as a minimum 40.13054301165688 TWh of energy

# %%
sha_256.apply(lambda x: lower_bound(x)*3600/10**12, axis=1)
# Out:
# Bitcoin           40.130543
# BitcoinCashABC     1.472058
# BitcoinSV          1.154531
# DGB-SHA            0.008688
# LitecoinCash       0.001109
# Myriad-SHA         3.265881
# Nicehash-SHA       0.145141
# Peercoin           0.000997
# dtype: float64

# %% [markdown]
# ## Reward to energy estimation

# %%
mining_data['reward_per_sec'] = mining_data['block_reward']*mining_data['exchange_rate']/mining_data['block_time']
mining_data
# Out:
#                  Market Cap ($)        Price  Volume (24h)  \
# Name
# bitcoin            1.582063e+11  8669.950000   36604114509
# ethereum           2.440093e+10   221.980000   17556366958
# bitcoincash        5.865094e+09   320.350000    4251315222
# bitcoinsv          4.250278e+09   232.180000    2250321444
# litecoin           3.801726e+09    59.210000    4433870551
# cardano            1.226269e+09     0.047297     102267054
# monero             1.159233e+09    66.370000     101835102
# tron               1.123979e+09     0.016856    1570324125
# ethereumclassic    9.465897e+08     8.140000    1614433225
# dash               8.145112e+08    87.020000     747414446
# zcash              4.609111e+08    50.030000     311995941
# dogecoin           2.820381e+08     0.002283     166256231
# algorand           1.930636e+08     0.328960      93702462
# decred             1.891563e+08    17.540000     102700127
# bitcoingold        1.700709e+08     9.710000      39606584
# ravencoin          1.444625e+08     0.025655      10194739
# bitcoindiamond     1.221663e+08     0.655072      11294459
# monacoin           1.108403e+08     1.690000       6100756
# siacoin            9.645836e+07     0.002307       1228490
# bytecoin           9.270225e+07     0.000504         19536
# horizen            8.559170e+07    10.020000       1543230
# bytom              7.823782e+07     0.078043      11905912
# komodo             7.592247e+07     0.640276       2536293
# digibyte           7.191128e+07     0.005583        824878
# hypercash          6.840370e+07     1.540000      24719969
# aion               6.181198e+07     0.154231       7094352
# zilliqa            5.992715e+07     0.006027      78526799
# verge              5.942903e+07     0.003670        691527
# aeternity          5.084859e+07     0.167894       9674993
# abbccoin           5.079806e+07     0.091459      28278377
# zcoin              4.857025e+07     5.070000       5757398
#
#                  Circulating Supply  code    algorithm    difficulty  \
# Name
# bitcoin                    18247675   BTC      SHA-256  1.554675e+13
# ethereum                  109925923   ETH       EtHash  2.244509e+15
# bitcoincash                18308363   BCH      SHA-256  5.728909e+11
# bitcoinsv                  18305602   BSV      SHA-256  4.315897e+11
# litecoin                   64202387   LTC       Scrypt  5.975834e+06
# cardano                 25927070538   ADA          PoS           NaN
# monero                     17466147   XMR      RandomX  1.576720e+11
# tron                    66682072191   TRX         DPoS           NaN
# ethereumclassic           116313299   ETC       EtHash  1.543936e+14
# dash                        9359544  DASH          X11  2.980434e+08
# zcash                       9212506   ZEC     Equihash  6.030782e+07
# dogecoin               123544326274  DOGE       Scrypt  2.453764e+06
# algorand                  586890345  ALGO          PoS           NaN
# decred                     10786831   DCR  Blake (14r)  2.670300e+10
# bitcoingold                17513924   BTG     Equihash  1.765900e+05
# ravencoin                5631060000   RVN       X16Rv2  4.358396e+05
# bitcoindiamond            186492898   BCD          BCD  6.421233e+06
# monacoin                   65729675  MONA    Lyra2REv2  2.581780e+06
# siacoin                 41817047634    SC      PoSpace           NaN
# bytecoin               184066828814   BCN  CryptoNight  8.129765e+09
# horizen                     8539588   ZEN     Equihash  1.404942e+07
# bytom                    1002499275   BTM         None           NaN
# komodo                    118577670   KMD     Equihash  2.007803e+08
# digibyte                12880917393   DGB       Scrypt  2.286140e+04
# hypercash                  44528736    HC         None           NaN
# aion                      400776284  AION         None           NaN
# zilliqa                  9942807276   ZIL         None           NaN
# verge                   16193811143   XVG       Scrypt  5.664491e+03
# aeternity                 302860498    AE         None           NaN
# abbccoin                  555416914  ABBC         None           NaN
# zcoin                       9586443   XZC         None           NaN
#
#                  block_time  block_reward  exchange_rate  position  \
# Name
# bitcoin               599.0     12.619200    9706.250000         0
# ethereum               15.0      2.000000     224.138591         1
# bitcoincash           600.0     12.500000     322.173093         3
# bitcoinsv             578.0     12.500000     285.189037         5
# litecoin              140.0     12.500000      75.559274         6
# cardano                 NaN           NaN            NaN        11
# monero                120.0      2.150000      66.854550        13
# tron                    NaN           NaN            NaN        14
# ethereumclassic        15.0      4.000000       8.145615        17
# dash                  155.0      1.553313     103.721376        18
# zcash                  75.0      5.000000      61.218484        25
# dogecoin               62.0  10000.000000       0.002604        32
# algorand                NaN           NaN            NaN        36
# decred                281.0      9.420478      21.449551        37
# bitcoingold           600.0           NaN            NaN        38
# ravencoin              60.0   5000.000000       0.025847        43
# bitcoindiamond        579.0    125.000000       0.726028        48
# monacoin               93.0     25.000000       1.860979        53
# siacoin                 NaN           NaN            NaN        58
# bytecoin              198.0    374.434699       0.000485        59
# horizen               150.0      7.500000      11.558203        63
# bytom                   NaN           NaN            NaN        67
# komodo                 62.0      3.000000       0.740587        69
# digibyte               15.0    665.639774       0.005608        71
# hypercash               NaN           NaN            NaN        73
# aion                    NaN           NaN            NaN        79
# zilliqa                 NaN           NaN            NaN        80
# verge                  30.0    730.000000       0.003680        81
# aeternity               NaN           NaN            NaN        89
# abbccoin                NaN           NaN            NaN        90
# zcoin                   NaN           NaN            NaN        93
#
#                  reward_per_sec
# Name
# bitcoin              204.482654
# ethereum              29.885145
# bitcoincash            6.711939
# bitcoinsv              6.167583
# litecoin               6.746364
# cardano                     NaN
# monero                 1.197811
# tron                        NaN
# ethereumclassic        2.172164
# dash                   1.039431
# zcash                  4.081232
# dogecoin               0.420077
# algorand                    NaN
# decred                 0.719093
# bitcoingold                 NaN
# ravencoin              2.153951
# bitcoindiamond         0.156742
# monacoin               0.500263
# siacoin                     NaN
# bytecoin               0.000918
# horizen                0.577910
# bytom                       NaN
# komodo                 0.035835
# digibyte               0.248842
# hypercash                   NaN
# aion                        NaN
# zilliqa                     NaN
# verge                  0.089546
# aeternity                   NaN
# abbccoin                    NaN
# zcoin                       NaN

# %%
sum_of_rewards = np.sum(mining_data['reward_per_sec'])
sum_of_rewards
# Out:
# 267.38749988175215

# %%
average_price = 0.14 # $ per kWh

# %%
sum_of_rewards/average_price
# Out:
# 1909.9107134410865
